# %% [markdown]
# # Colab fine-tuning (free T4)
# Fine-tune ResNet-50 (classification) and DeepLabV3-ResNet50 (segmentation) on a ~1-2k Oxford-IIIT Pet subset.
#
# **Runtime -> Change runtime type -> T4 GPU**, then run top to bottom.
#
# _Skeleton notebook — cells to be filled incrementally._

# %%
# Clone repo + install deps
# !git clone https://github.com/yonatan-gif/Image-Processing-Final-Project.git
# %cd Image-Processing-Final-Project
# !pip install -q -r requirements.txt
import torch; print('CUDA available:', torch.cuda.is_available())

# %%
# TODO: load subset, fine-tune classification (ResNet-50), save checkpoint

# %%
# TODO: fine-tune segmentation (DeepLabV3-ResNet50), save checkpoint
